# %% [markdown]
# # Ouroboros Google Colab Quickstart
#
# This is the official Ouroboros Google Colab notebook wrapper. It allows you to run Ouroboros in a headless source-mode inside Colab and communicate with it bidirectionally via Telegram.
#
# ### Step 1: Set up your API Keys below.

# %%
# WARNING: For your security, NEVER commit or share this notebook with your actual keys written here!
# (For maximum security, use the Colab secrets/keys menu on the left and fetch via google.colab.userdata.get)
OPENROUTER_API_KEY = ""
TELEGRAM_BOT_TOKEN = ""

# %% [markdown]
# ### Step 2: Download the Bootstrap Script and Run Ouroboros
#
# The code below downloads `colab_quickstart.py` from the Ouroboros repository and executes it. This mounts Google Drive to preserve your identity/scratchpad, sets up the server, downloads the Telegram bridge, and starts everything up.

# %%
import os

# !curl -s -L -o colab_quickstart.py https://raw.githubusercontent.com/razzant/Ouroboros/ouroboros/notebooks/colab_quickstart.py

os.environ["OPENROUTER_API_KEY"] = OPENROUTER_API_KEY
os.environ["TELEGRAM_BOT_TOKEN"] = TELEGRAM_BOT_TOKEN

# %run colab_quickstart.py

# %% [markdown]
# ### Step 3: Diagnostic Cell (Optional)
#
# Run the cell below any time if you want to verify that the Ouroboros background processes are active.

# %%
# !ps aux | grep python3
